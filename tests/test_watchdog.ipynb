# %%
import sys

sys.path.insert(0, "/home/jovyan/apps/aiidalab-openbis/")

# %%
openbis_url = "https://localhost.openbis.net"
token = "$pat-admin-260529072747264x9E42A31F4E96D5689DCFD62F9E2A1D97"
data_folder = "/home/jovyan/openBIS_measurements/Test data/"
sample = "20260529074623357-4234"
logging_filepath = "/home/jovyan/openBIS_measurements/Test data/logging.json"
# process_measurement_files(openbis_url, token, data_folder, sample, logging_filepath)

# %%
import subprocess

subprocess.run(
    [
        "python3",
        "/home/jovyan/apps/aiidalab-openbis/src/measurements_uploader.py",
        "--openbis_url",
        openbis_url,
        "--openbis_token",
        token,
        "--measurement_session_id",
        sample,
        "--data_folder",
        data_folder,
    ]
)
